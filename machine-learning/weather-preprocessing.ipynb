# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objs as go
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import TimeSeriesSplit
import lightgbm as lgb
import pyarrow

# %%
filepath = 'sample-data/weather_data_10_years.csv'

df = pd.read_csv(filepath)

df.head()
# Out:
#            dt                         dt_iso  timezone  \
# 0  1394064000  2014-03-06 00:00:00 +0000 UTC    -28800
# 1  1394067600  2014-03-06 01:00:00 +0000 UTC    -28800
# 2  1394071200  2014-03-06 02:00:00 +0000 UTC    -28800
# 3  1394074800  2014-03-06 03:00:00 +0000 UTC    -28800
# 4  1394078400  2014-03-06 04:00:00 +0000 UTC    -28800
#
#                             city_name        lat         lon  temp  \
# 0  The University of British Columbia  49.260605 -123.245994  9.79
# 1  The University of British Columbia  49.260605 -123.245994  9.75
# 2  The University of British Columbia  49.260605 -123.245994  9.21
# 3  The University of British Columbia  49.260605 -123.245994  8.67
# 4  The University of British Columbia  49.260605 -123.245994  8.00
#
#    visibility  dew_point  feels_like  ...  wind_gust  rain_1h  rain_3h  \
# 0     10000.0       7.22        6.76  ...        NaN      NaN      NaN
# 1     10000.0       7.01        6.56  ...        NaN      NaN      NaN
# 2     10000.0       6.65        6.36  ...        NaN      NaN      NaN
# 3     10000.0       6.12        6.08  ...        NaN     0.21      NaN
# 4     10000.0       6.14        5.25  ...        NaN     0.30      NaN
#
#    snow_1h  snow_3h  clouds_all  weather_id  weather_main  \
# 0      NaN      NaN          75         803        Clouds
# 1      NaN      NaN         100         804        Clouds
# 2      NaN      NaN         100         804        Clouds
# 3      NaN      NaN         100         500          Rain
# 4      NaN      NaN         100         500          Rain
#
#    weather_description  weather_icon
# 0        broken clouds           04d
# 1      overcast clouds           04d
# 2      overcast clouds           04d
# 3           light rain           10n
# 4           light rain           10n
#
# [5 rows x 28 columns]

# %%
# Specify the columns you want to keep
columns_to_keep = ['dt_iso', 'temp', 'visibility', 'dew_point', 'feels_like', 'pressure', 'humidity', 'wind_speed', 'clouds_all', 'rain_1h', 'snow_1h', 'weather_main', 'weather_description']

# Filter the DataFrame to include only the desired columns
df = df[columns_to_keep]

df.head()
# Out:
#                           dt_iso  temp  visibility  dew_point  feels_like  \
# 0  2014-03-06 00:00:00 +0000 UTC  9.79     10000.0       7.22        6.76
# 1  2014-03-06 01:00:00 +0000 UTC  9.75     10000.0       7.01        6.56
# 2  2014-03-06 02:00:00 +0000 UTC  9.21     10000.0       6.65        6.36
# 3  2014-03-06 03:00:00 +0000 UTC  8.67     10000.0       6.12        6.08
# 4  2014-03-06 04:00:00 +0000 UTC  8.00     10000.0       6.14        5.25
#
#    pressure  humidity  wind_speed  clouds_all  rain_1h  snow_1h weather_main  \
# 0      1001        84        6.70          75      NaN      NaN       Clouds
# 1      1000        83        7.20         100      NaN      NaN       Clouds
# 2       998        84        5.66         100      NaN      NaN       Clouds
# 3       998        84        4.63         100     0.21      NaN         Rain
# 4       997        88        4.63         100     0.30      NaN         Rain
#
#   weather_description
# 0       broken clouds
# 1     overcast clouds
# 2     overcast clouds
# 3          light rain
# 4          light rain

# %%
# Extract first 10 characters from each value in 'dt_iso' column
df['Timestamp'] = df['dt_iso'].str[:19]
df.drop(['dt_iso'], axis=1, inplace=True)

# Reorganize the order of columns with 'Timestamp' at the beginning
df = df[['Timestamp'] + [col for col in df.columns if col != 'Timestamp']]

print(df)
# Out:
#                  Timestamp  temp  visibility  dew_point  feels_like  pressure  \
# 0      2014-03-06 00:00:00  9.79     10000.0       7.22        6.76      1001
# 1      2014-03-06 01:00:00  9.75     10000.0       7.01        6.56      1000
# 2      2014-03-06 02:00:00  9.21     10000.0       6.65        6.36       998
# 3      2014-03-06 03:00:00  8.67     10000.0       6.12        6.08       998
# 4      2014-03-06 04:00:00  8.00     10000.0       6.14        5.25       997
# ...                    ...   ...         ...        ...         ...       ...
# 90993  2024-03-05 19:00:00  3.21     10000.0      -0.53        1.22      1017
# 90994  2024-03-05 20:00:00  4.18     10000.0      -1.41        0.78      1018
# 90995  2024-03-05 21:00:00  4.17     10000.0      -1.06        0.49      1018
# 90996  2024-03-05 22:00:00  4.57     10000.0      -1.45        1.26      1018
# 90997  2024-03-05 23:00:00  4.68     10000.0      -1.55        2.46      1017
#
#        humidity  wind_speed  clouds_all  rain_1h  snow_1h weather_main  \
# 0            84        6.70          75      NaN      NaN       Clouds
# 1            83        7.20         100      NaN      NaN       Clouds
# 2            84        5.66         100      NaN      NaN       Clouds
# 3            84        4.63         100     0.21      NaN         Rain
# 4            88        4.63         100     0.30      NaN         Rain
# ...         ...         ...         ...      ...      ...          ...
# 90993        76        2.06          75      NaN      NaN       Clouds
# 90994        66        4.12          20      NaN      NaN       Clouds
# 90995        68        4.63          20      NaN      NaN       Clouds
# 90996        64        4.12          20      NaN      NaN       Clouds
# 90997        63        2.57          40      NaN      NaN       Clouds
#
#       weather_description
# 0           broken clouds
# 1         overcast clouds
# 2         overcast clouds
# 3              light rain
# 4              light rain
# ...                   ...
# 90993       broken clouds
# 90994          few clouds
# 90995          few clouds
# 90996          few clouds
# 90997    scattered clouds
#
# [90998 rows x 13 columns]

# %%
# Combine 'weather_main' and 'weather_description' into a single feature
df['combined_weather'] = df['weather_main'] + "_" + df['weather_description']

# One-hot encoding for the combined feature
one_hot_encoded = pd.get_dummies(df['combined_weather'], prefix='weather')

# Concatenate the one-hot encoded feature with the original DataFrame
df_encoded = pd.concat([df, one_hot_encoded], axis=1)

# Drop the original 'weather_main' and 'weather_description' columns
df_encoded.drop(['weather_main', 'weather_description', 'combined_weather'], axis=1, inplace=True)

print(df_encoded)
# Out:
#                  Timestamp  temp  visibility  dew_point  feels_like  pressure  \
# 0      2014-03-06 00:00:00  9.79     10000.0       7.22        6.76      1001
# 1      2014-03-06 01:00:00  9.75     10000.0       7.01        6.56      1000
# 2      2014-03-06 02:00:00  9.21     10000.0       6.65        6.36       998
# 3      2014-03-06 03:00:00  8.67     10000.0       6.12        6.08       998
# 4      2014-03-06 04:00:00  8.00     10000.0       6.14        5.25       997
# ...                    ...   ...         ...        ...         ...       ...
# 90993  2024-03-05 19:00:00  3.21     10000.0      -0.53        1.22      1017
# 90994  2024-03-05 20:00:00  4.18     10000.0      -1.41        0.78      1018
# 90995  2024-03-05 21:00:00  4.17     10000.0      -1.06        0.49      1018
# 90996  2024-03-05 22:00:00  4.57     10000.0      -1.45        1.26      1018
# 90997  2024-03-05 23:00:00  4.68     10000.0      -1.55        2.46      1017
#
#        humidity  wind_speed  clouds_all  rain_1h  ...  \
# 0            84        6.70          75      NaN  ...
# 1            83        7.20         100      NaN  ...
# 2            84        5.66         100      NaN  ...
# 3            84        4.63         100     0.21  ...
# 4            88        4.63         100     0.30  ...
# ...         ...         ...         ...      ...  ...
# 90993        76        2.06          75      NaN  ...
# 90994        66        4.12          20      NaN  ...
# 90995        68        4.63          20      NaN  ...
# 90996        64        4.12          20      NaN  ...
# 90997        63        2.57          40      NaN  ...
#
#        weather_Snow_light rain and snow  weather_Snow_light shower sleet  \
# 0                                 False                            False
# 1                                 False                            False
# 2                                 False                            False
# 3                                 False                            False
# 4                                 False                            False
# ...                                 ...                              ...
# 90993                             False                            False
# 90994                             False                            False
# 90995                             False                            False
# 90996                             False                            False
# 90997                             False                            False
#
#        weather_Snow_light shower snow  weather_Snow_light snow  \
# 0                               False                    False
# 1                               False                    False
# 2                               False                    False
# 3                               False                    False
# 4                               False                    False
# ...                               ...                      ...
# 90993                           False                    False
# 90994                           False                    False
# 90995                           False                    False
# 90996                           False                    False
# 90997                           False                    False
#
#        weather_Snow_sleet  weather_Snow_snow  \
# 0                   False              False
# 1                   False              False
# 2                   False              False
# 3                   False              False
# 4                   False              False
# ...                   ...                ...
# 90993               False              False
# 90994               False              False
# 90995               False              False
# 90996               False              False
# 90997               False              False
#
#        weather_Thunderstorm_thunderstorm  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
# ...                                  ...
# 90993                              False
# 90994                              False
# 90995                              False
# 90996                              False
# 90997                              False
#
#        weather_Thunderstorm_thunderstorm with heavy rain  \
# 0                                                  False
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 4                                                  False
# ...                                                  ...
# 90993                                              False
# 90994                                              False
# 90995                                              False
# 90996                                              False
# 90997                                              False
#
#        weather_Thunderstorm_thunderstorm with light rain  \
# 0                                                  False
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 4                                                  False
# ...                                                  ...
# 90993                                              False
# 90994                                              False
# 90995                                              False
# 90996                                              False
# 90997                                              False
#
#        weather_Thunderstorm_thunderstorm with rain
# 0                                            False
# 1                                            False
# 2                                            False
# 3                                            False
# 4                                            False
# ...                                            ...
# 90993                                        False
# 90994                                        False
# 90995                                        False
# 90996                                        False
# 90997                                        False
#
# [90998 rows x 44 columns]

# %%
df_encoded.to_csv('weather_data_10_years_preprocessed.csv', index=False)
