# %%
import pandas as pd

# %%
weather_df = pd.read_csv('./../sample-data/weather_data_10_years_preprocessed.csv')

weather_df.head()
# Out:
#              Timestamp  temp  visibility  dew_point  feels_like  pressure  \
# 0  2014-03-06 00:00:00  9.79     10000.0       7.22        6.76      1001
# 1  2014-03-06 01:00:00  9.75     10000.0       7.01        6.56      1000
# 2  2014-03-06 02:00:00  9.21     10000.0       6.65        6.36       998
# 3  2014-03-06 03:00:00  8.67     10000.0       6.12        6.08       998
# 4  2014-03-06 04:00:00  8.00     10000.0       6.14        5.25       997
#
#    humidity  wind_speed  clouds_all  rain_1h  snow_1h
# 0        84        6.70          75      NaN      NaN
# 1        83        7.20         100      NaN      NaN
# 2        84        5.66         100      NaN      NaN
# 3        84        4.63         100     0.21      NaN
# 4        88        4.63         100     0.30      NaN

# %%
import pandas as pd

# Load the data from CSV
parking_df = pd.read_csv('./../sample-data/combined_parking_data.csv')

# Rename the 'Hour' column to 'Timestamp'
#parking_df.rename(columns={'Hour': 'Timestamp'}, inplace=True)

# Display the first few rows of the DataFrame to verify the change
print(parking_df.head())
# Out:
#              Timestamp  North    West  Rose  Health Sciences  Fraser  \
# 0  2018-09-06 09:00:00    950  1015.0   475              909     556
# 1  2018-09-06 10:00:00    918  1160.0   612              972     706
# 2  2018-09-06 10:00:00    951  1016.0   476              913     556
# 3  2018-09-06 11:00:00    922  1160.0   609              972     707
# 4  2018-09-06 11:00:00    832  1210.0   659              964     724
#
#    Thunderbird  University Lot Blvd  Unnamed: 0
# 0          934                  NaN         0.0
# 1         1049                  NaN         1.0
# 2          939                 -1.0         NaN
# 3         1050                 -1.0         NaN
# 4         1072                  NaN         2.0

# %%
# Merge the two DataFrames on 'Timestamp'
combined_df = pd.merge(parking_df, weather_df, on='Timestamp')

print(combined_df)
# Out:
#                   Timestamp  North    West  Rose  Health Sciences  Fraser  \
# 0       2018-09-06 09:00:00    950  1015.0   475              909     556
# 1       2018-09-06 10:00:00    918  1160.0   612              972     706
# 2       2018-09-06 10:00:00    951  1016.0   476              913     556
# 3       2018-09-06 11:00:00    922  1160.0   609              972     707
# 4       2018-09-06 11:00:00    832  1210.0   659              964     724
# ...                     ...    ...     ...   ...              ...     ...
# 103972  2024-07-02 19:00:00    428   521.0   225              783     203
# 103973  2024-07-02 20:00:00    435   539.0   241              803     204
# 103974  2024-07-02 21:00:00    383   536.0   220              805     188
# 103975  2024-07-02 22:00:00    286   351.0   194              687     175
# 103976  2024-07-02 23:00:00    184   203.0    96              546      97
#
#         Thunderbird  University Lot Blvd  Unnamed: 0   temp  visibility  \
# 0               934                  NaN         0.0  14.69     10000.0
# 1              1049                  NaN         1.0  14.59     10000.0
# 2               939                 -1.0         NaN  14.59     10000.0
# 3              1050                 -1.0         NaN  14.01     10000.0
# 4              1072                  NaN         2.0  14.01     10000.0
# ...             ...                  ...         ...    ...         ...
# 103972          480                 73.0     51034.0  18.06     10000.0
# 103973          482                 76.0     51035.0  18.46     10000.0
# 103974          437                 69.0     51036.0  18.47     10000.0
# 103975          359                 83.0     51037.0  19.13     10000.0
# 103976          199                 41.0     51038.0  19.62     10000.0
#
#         dew_point  feels_like  pressure  humidity  wind_speed  clouds_all  \
# 0           11.09       14.28      1015        79        1.54          20
# 1           10.21       14.06      1015        75        1.03          20
# 2           10.21       14.06      1015        75        1.03          20
# 3            9.85       13.45      1016        76        0.00          40
# 4            9.85       13.45      1016        76        0.00          40
# ...           ...         ...       ...       ...         ...         ...
# 103972      12.94       17.80      1023        72        4.63          20
# 103973      13.32       18.24      1023        72        6.26          20
# 103974      13.12       18.23      1023        71        5.36          20
# 103975      12.63       18.82      1023        66        6.17          20
# 103976      11.65       19.20      1022        60        4.12          20
#
#         rain_1h  snow_1h
# 0           NaN      NaN
# 1           NaN      NaN
# 2           NaN      NaN
# 3           NaN      NaN
# 4           NaN      NaN
# ...         ...      ...
# 103972      NaN      NaN
# 103973      NaN      NaN
# 103974      NaN      NaN
# 103975      NaN      NaN
# 103976      NaN      NaN
#
# [103977 rows x 19 columns]

# %%
combined_df.to_csv('./../sample-data/combined_weather_parking.csv', index=False)

# %%
# Filter rows where timestamp is outside of the specified range
combined_df = combined_df[(combined_df['Timestamp'] < '2020-03-15') | (combined_df['Timestamp'] > '2021-09-07')]
# Drop duplicates, keeping the most recent entry for each timestamp
combined_df = combined_df.drop_duplicates(subset='Timestamp', keep='last')

combined_df.to_csv('./../sample-data/combined_weather_parking_WO2020_no_dups.csv', index=False)
